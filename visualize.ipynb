# %% [markdown]
# ### Visualize InLab Videos
# ___*inlab3.mp4__ is not valid without a new transformation, as the video is recorded with different frame._

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# "inlab1"
# Load waypoints
file_name = "inlab1"
output_dir = f"./Recorded Datasets/inlabs/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full.txt"), delimiter="\t", comments=None, dtype=str) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz.txt"), delimiter="\t", comments=None, dtype=str)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()

# %%
# "inlab2"
# Load waypoints
file_name = "inlab2"
output_dir = f"./Recorded Datasets/inlabs/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full.txt"), delimiter="\t", comments=None, dtype=str) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz.txt"), delimiter="\t", comments=None, dtype=str)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()

# %%
# "inlab3"
# Load waypoints
file_name = "inlab3"
output_dir = f"./Recorded Datasets/inlabs/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full.txt"), delimiter="\t", comments=None, dtype=str) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz.txt"), delimiter="\t", comments=None, dtype=str)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()

# %%
# "inlab4"
# Load waypoints
file_name = "inlab4"
output_dir = f"./Recorded Datasets/inlabs/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full.txt"), delimiter="\t", comments=None, dtype=str) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz.txt"), delimiter="\t", comments=None, dtype=str)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()

# %%
# "inlab5"
# Load waypoints
file_name = "inlab5"
output_dir = f"./Recorded Datasets/inlabs/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full.txt"), delimiter="\t", comments=None, dtype=str) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz.txt"), delimiter="\t", comments=None, dtype=str)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()

# %% [markdown]
# ### Evaluate InLab Videos

# %% [markdown]
# #### inlab_eval_1

# %%
# Load waypoints
file_name = "inlab_eval_1"
output_dir = f"./Recorded Datasets/inlab_evals/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates

P_o = np.array([193, 91, 0])
P_d = np.array([193, 391, 0])
plt.plot(*zip(P_o[:2], P_d[:2]), marker="o", linestyle="--", color="red")
plt.grid(True)
plt.show()


# Calculate deviation from the actual line
dist = []
for point in waypoints[:, 2:]:
    point = np.append(point, 0) # Add z coordinate, to comply with linalg's new convention
    dist.append(np.linalg.norm(np.cross(P_o-P_d, P_d-point))/np.linalg.norm(P_o-P_d))

print(f"The average deviation from the atual line is:\t {np.average(dist):.2f} cm")
print(f"The std deviation from the atual line is:\t {np.std(dist):.2f} cm")
# Out:
# The average deviation from the atual line is:	 6.67 cm
# The std deviation from the atual line is:	 5.53 cm

# %% [markdown]
# #### inlab_eval_2

# %%
# Load waypoints
file_name = "inlab_eval_2"
output_dir = f"./Recorded Datasets/inlab_evals/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates

P_o = np.array([193, 391, 0])
P_d = np.array([433, 151, 0])
plt.plot(*zip(P_o[:2], P_d[:2]), marker="o", linestyle="--", color="red")
plt.grid(True)
plt.show()

dist = []
for point in waypoints[:, 2:]:
    point = np.append(point, 0)
    dist.append(np.linalg.norm(np.cross(P_o-P_d, P_d-point))/np.linalg.norm(P_o-P_d))

print(f"The average deviation from the atual line is:\t {np.average(dist):.2f} cm")
print(f"The std deviation from the atual line is:\t {np.std(dist):.2f} cm")
# Out:
# The average deviation from the atual line is:	 3.32 cm
# The std deviation from the atual line is:	 2.52 cm

# %% [markdown]
# #### inlab_eval_3

# %%
# Load waypoints
file_name = "inlab_eval_3"
output_dir = f"./Recorded Datasets/inlab_evals/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates

P_o = np.array([13, 271, 0])
P_d = np.array([373, 271, 0])
plt.plot(*zip(P_o[:2], P_d[:2]), marker="o", linestyle="--", color="red")
plt.grid(True)
plt.show()

dist = []
for point in waypoints[:, 2:]:
    point = np.append(point, 0)
    dist.append(np.linalg.norm(np.cross(P_o-P_d, P_d-point))/np.linalg.norm(P_o-P_d))

print(f"The average deviation from the atual line is:\t {np.average(dist):.2f} cm")
print(f"The std deviation from the atual line is:\t {np.std(dist):.2f} cm")
# Out:
# The average deviation from the atual line is:	 10.54 cm
# The std deviation from the atual line is:	 4.48 cm

# %% [markdown]
# #### inlab_eval_4

# %%
# Load waypoints
file_name = "inlab_eval_4"
output_dir = f"./Recorded Datasets/inlab_evals/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates

P_1 = np.array([133, 331, 0])
P_2 = np.array([133, 151, 0])
P_3 = np.array([373, 151, 0])
P_4 = np.array([373, 271, 0])
plt.plot(*zip(P_1[:2], P_2[:2], P_3[:2], P_4[:2]), marker="o", linestyle="--", color="red")
plt.grid(True)
plt.show()

dist = []
for point in waypoints[:, 2:]:
    point = np.append(point, 0)
    if(point[0] < 150 and point[1] > 150):
        dist.append(np.linalg.norm(np.cross(P_1-P_2, P_2-point))/np.linalg.norm(P_1-P_2))
    elif(point[0] > 125 and point[1] < 151):
        dist.append(np.linalg.norm(np.cross(P_2-P_3, P_3-point))/np.linalg.norm(P_2-P_3))
    elif(point[0] > 350 and point[1] > 150):
        dist.append(np.linalg.norm(np.cross(P_3-P_4, P_4-point))/np.linalg.norm(P_3-P_4))
    else:
        continue
    

print(f"The average deviation from the atual line is:\t {np.average(dist):.2f} cm")
print(f"The std deviation from the atual line is:\t {np.std(dist):.2f} cm")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 6
#       3 output_dir = f"./Recorded Datasets/inlab_evals/{file_name}"
#       5 # waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
# ----> 6 waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
#       7 waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)
#       9 # Plot waypoints
#
# File ~/miniconda3/envs/yolotracker/lib/python3.13/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
# ...

# %% [markdown]
# #### inlab_eval_5

# %%
# Load waypoints
file_name = "inlab_eval_5"
output_dir = f"./Recorded Datasets/inlab_evals/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates

P_1 = np.array([133, 391, 0])
P_2 = np.array([373, 151, 0])
P_3 = np.array([133, 151, 0])
P_4 = np.array([133, 391, 0])
plt.plot(*zip(P_1[:2], P_2[:2], P_3[:2], P_4[:2]), marker="o", linestyle="--", color="red")
plt.grid(True)
plt.show()

dist = []
for point in waypoints[:, 2:]:
    point = np.append(point, 0)
    if(point[0] < 150 and point[1] > 150):
        dist.append(np.linalg.norm(np.cross(P_3-P_1, P_3-point))/np.linalg.norm(P_3-P_1))
    elif(point[0] > 125 and point[1] < 151):
        dist.append(np.linalg.norm(np.cross(P_3-P_2, P_2-point))/np.linalg.norm(P_3-P_2))
    elif(point[0] > 150 and point[1] > 155):
        dist.append(np.linalg.norm(np.cross(P_2-P_4, P_4-point))/np.linalg.norm(P_2-P_4))
        continue
    else:
        continue
    

print(f"The average deviation from the actual line is:\t {np.average(dist):.2f} cm")
print(f"The std deviation from the actual line is:\t {np.std(dist):.2f} cm")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 6
#       3 output_dir = f"./Recorded Datasets/inlab_evals/{file_name}"
#       5 # waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
# ----> 6 waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
#       7 waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)
#       9 # Plot waypoints
#
# File ~/miniconda3/envs/yolotracker/lib/python3.13/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
# ...

# %% [markdown]
# | Scenario | Description | Average Distance (cm) | Standard Deviation (cm) |
# |----------|-------------------------|------------------------|----|
# | ilab_eval_1    | Straight vertical line            | 7.17                   |   6.00      |
# | ilab_eval_2    | Straight diagonal line            | 3.36                   |     2.42    |
# | ilab_eval_3    | Straight horizontal line             | 10.81                  |   4.65      |
# | ilab_eval_4    | Upside-down U path             | 7.77                  |   5.93      |
# | ilab_eval_5    | Triangle path            | 8.06                | 6.42        |

# %% [markdown]
# ## Visualize Maneuvers

# %% [markdown]
# ### Maneuver 1

# %%
# Load waypoints
file_name = "maneuver_1"
output_dir = f"./Recorded Datasets/maneuvers/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()

# %% [markdown]
# ### Maneuver 2

# %%
# Load waypoints
file_name = "maneuver_2"
output_dir = f"./Recorded Datasets/maneuvers/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()

# %% [markdown]
# ### Maneuver 3

# %%
# Load waypoints
file_name = "maneuver_3"
output_dir = f"./Recorded Datasets/maneuvers/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()

# %% [markdown]
# ### Maneuver 4

# %%
# Load waypoints
file_name = "maneuver_4"
output_dir = f"./Recorded Datasets/maneuvers/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 6
#       3 output_dir = f"./Recorded Datasets/maneuvers/{file_name}"
#       5 # waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
# ----> 6 waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
#       7 waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)
#       9 # Plot waypoints
#
# File ~/miniconda3/envs/yolotracker/lib/python3.13/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
# ...

# %% [markdown]
# ### Maneuver 5

# %%
# Load waypoints
file_name = "maneuver_5"
output_dir = f"./Recorded Datasets/maneuvers/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 6
#       3 output_dir = f"./Recorded Datasets/maneuvers/{file_name}"
#       5 # waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
# ----> 6 waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
#       7 waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)
#       9 # Plot waypoints
#
# File ~/miniconda3/envs/yolotracker/lib/python3.13/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
# ...

# %% [markdown]
# ### Maneuver 6

# %%
# Load waypoints
file_name = "maneuver_6"
output_dir = f"./Recorded Datasets/maneuvers/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 6
#       3 output_dir = f"./Recorded Datasets/maneuvers/{file_name}"
#       5 # waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
# ----> 6 waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
#       7 waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)
#       9 # Plot waypoints
#
# File ~/miniconda3/envs/yolotracker/lib/python3.13/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
# ...

# %% [markdown]
# ### Maneuver 7

# %%
# Load waypoints
file_name = "maneuver_7"
output_dir = f"./Recorded Datasets/maneuvers/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 6
#       3 output_dir = f"./Recorded Datasets/maneuvers/{file_name}"
#       5 # waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1) # Includes None values
# ----> 6 waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
#       7 waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)
#       9 # Plot waypoints
#
# File ~/miniconda3/envs/yolotracker/lib/python3.13/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
# ...

# %% [markdown]
# ## In Lab videos with Box

# %% [markdown]
# ### Plot inlab video with box frame

# %%
# With Box Frame

# Load waypoints
file_name = "inlab1"
output_dir = f"./Recorded Datasets/inlabs/{file_name}"

# waypoints = np.loadtxt(os.path.join(output_dir, "box_waypoints.txt"), delimiter="\t") # Includes None values
waypoints = np.loadtxt(os.path.join(output_dir, "box_waypoints_sampled.txt"), delimiter="\t")
# waypoints = np.loadtxt(os.path.join(output_dir, "box_waypoints_smoothed.txt"), delimiter="\t")

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
# plt.xlim(0, 350)
# plt.ylim(125, 375)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()

# %% [markdown]
# # Plot the unified dataset
# ## Straight line

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# "inlab1"
# Load waypoints
traj_type = 'Vertical Line' # Horizontal Line, Diagonal Line, Vertical Line
file_name = "VL_C_F_BU_1"
output_dir = f"./Recorded Datasets/Straight Line/{traj_type}/{file_name}"

waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)
print(len(waypoints))

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()
# Out:
# 54

# %% [markdown]
# ## Other Paths

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# "inlab1"
# Load waypoints
traj_type = 'Square Path' # Infinity Loop, Circular Path, Square Path
file_name = "SP_C_F_CW_1"
output_dir = f"./Recorded Datasets/{traj_type}/{file_name}"

waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)
print(len(waypoints))

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()
# Out:
# 202

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# "inlab1"
# Load waypoints
traj_type = 'Square Path' # Infinity Loop, Circular Path, Square Path
file_name = "IL_1"
output_dir = f"./Recorded Datasets/{file_name}"

waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_full_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
# waypoints = np.loadtxt(os.path.join(output_dir, "pose_waypoints_sampled_10hz_raw.csv"), delimiter=",", comments=None, dtype=str, skiprows=1)
waypoints = np.array([row for row in waypoints if "None" not in row], dtype=float)
print(len(waypoints))

# Plot waypoints
plt.plot(waypoints[:, 2], waypoints[:, 3], marker="o", linestyle="-", color="blue")
plt.title("Person's Foot Movement Path")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.xlim(0, 433)
plt.ylim(0, 391)
plt.gca().invert_yaxis()  # Invert Y to match video coordinates
plt.gca().invert_xaxis()  # Invert X to match video coordinates
plt.grid(True)
plt.show()
# Out:
# 1282
